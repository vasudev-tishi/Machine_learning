# %% [markdown]
# #**IMPORTING REQUIRED LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #**READING THE DATA**

# %%
# Load the data (make sure 'Student_Performance (2).csv' exists)
try:
  df = pd.read_csv('Student_Performance (2).csv')
except FileNotFoundError:
  print("Error: 'Student_Performance (2).csv' not found. Please upload the file or provide the correct path.")
  exit()
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
# showing data table matrix from top (by default 5 index)
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
# showing data table matrix from bottom (by default 5 index)
df.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %% [markdown]
# #**CHECKING THE BASIC INFO**

# %%
# display basic information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
# describing the shape of the matrix
df.shape
# Out:
# (10000, 6)

# %%
# describing the basic information of matrix in transpose from
df.describe().T
# Out:
#                                     count     mean        std   min   25%  \
# Hours Studied                     10000.0   4.9929   2.589309   1.0   3.0
# Previous Scores                   10000.0  69.4457  17.343152  40.0  54.0
# Sleep Hours                       10000.0   6.5306   1.695863   4.0   5.0
# Sample Question Papers Practiced  10000.0   4.5833   2.867348   0.0   2.0
# Performance Index                 10000.0  55.2248  19.212558  10.0  40.0
#
#                                    50%   75%    max
# Hours Studied                      5.0   7.0    9.0
# Previous Scores                   69.0  85.0   99.0
# Sleep Hours                        7.0   8.0    9.0
# Sample Question Papers Practiced   5.0   7.0    9.0
# Performance Index                 55.0  71.0  100.0

# %%
# checking for missing values
df.isnull().sum().T
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %% [markdown]
# #**CHECKING FOR CATEGORICAL VALUE**

# %%
# exploring categorical features
for column in df.select_dtypes(include=['object']):
    print(f"\nValue counts for {column}:")
    print(df[column].value_counts())
# Out:
# Value counts for Extracurricular Activities:
# Extracurricular Activities
# No     5052
# Yes    4948
# Name: count, dtype: int64

# %%
# showing cateorical value in graph format
for column in df.select_dtypes(include=['object']):
  plt.figure(figsize=(8, 6))
  sns.countplot(x=column, data=df)
  plt.title(f'Distribution of {column}')
  plt.show()

# %% [markdown]
# #**CHECKING FOR NUMERICAL VALUES**

# %%
# Analyze numerical features
for column in df.select_dtypes(include=['int64', 'float64']):
    plt.figure(figsize=(8, 6))
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()

# %%
for column in df.select_dtypes(include=['int64', 'float64']):
    plt.figure(figsize=(8, 6))
    plt.hist(df[column], bins=20) # Adjust 'bins' as needed
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
for column in df.select_dtypes(include=['int64', 'float64']):
    plt.figure(figsize=(8, 6))
    df[column].value_counts().plot(kind='bar')
    plt.title(f'Bar plot of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
for column in df.select_dtypes(include=['int64', 'float64']):
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=column, data=df)
    plt.title(f'Box Plot of {column}')
    plt.show()

# %%
# droping
df=df.drop('Extracurricular Activities',axis=1)

# %%
# Correlation matrix using scatter plot
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.scatterplot(correlation_matrix)
plt.title('Correlation Matrix')
plt.show()

# %%
# Plotting the correlation matrix with heatmap
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.show()

# %%
for column in df.select_dtypes(include=['int64', 'float64']):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# %%
# Check the distribution of a numerical feature after cleaning
for column in df.select_dtypes(include=['int64', 'float64']):
    plt.figure(figsize=(8, 6))
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribution of {column} (After Cleaning)')
    plt.show()

# %%
# Analyze numerical features after outlier removal
for column in df.select_dtypes(include=['int64', 'float64']):
    plt.figure(figsize=(8, 6))
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribution of {column} (After Outlier Removal)')
    plt.show()

    plt.figure(figsize=(8, 6))
    plt.hist(df[column], bins=20)  # Adjust 'bins' as needed
    plt.title(f'Histogram of {column} (After Outlier Removal)')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

    plt.figure(figsize=(8, 6))
    df[column].value_counts().plot(kind='bar')
    plt.title(f'Bar plot of {column} (After Outlier Removal)')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

    plt.figure(figsize=(8, 6))
    sns.boxplot(x=column, data=df)
    plt.title(f'Box Plot of {column} (After Outlier Removal)')
    plt.show()

# %%
# Check the shape of the DataFrame after outlier removal
df.shape
# Out:
# (10000, 5)

# %%
# Verify the consistency of categorical values
for column in df.select_dtypes(include=['object']):
    print(f"\nValue counts for {column}:")
    print(df[column].value_counts())
    # Check for unexpected values or inconsistencies
    # Example: Check if there are any misspelled categories
    # You can add more specific checks here based on the expected values.
    # Example: Check for typos in a column named 'City'
    if column == 'City':
      # ... add your specific check here
      pass

# %%
# Pairplot for numerical features
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
if numerical_features:
    sns.pairplot(df[numerical_features])
    plt.show()


# Analyze the relationship between numerical and categorical features using box plots
for num_col in df.select_dtypes(include=['int64', 'float64']):
  for cat_col in df.select_dtypes(include=['object']):
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=cat_col, y=num_col, data=df)
    plt.title(f'Boxplot of {num_col} by {cat_col}')
    plt.show()
